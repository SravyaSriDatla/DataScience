# %% [markdown]
# <a href="https://colab.research.google.com/github/SravyaSriDatla/DataScience/blob/main/ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
emp = pd.read_excel('Rawdata.xlsx')

# %%
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 416.0+ bytes

# %%
emp.isnull()
# Out:
#     Name  Domain    Age  Location  Salary    Exp
# 0  False   False  False     False   False  False
# 1  False   False  False     False   False  False
# 2  False   False   True      True   False  False
# 3  False   False   True     False   False   True
# 4  False   False  False      True   False  False
# 5  False   False  False     False   False  False

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
emp['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp['Name'] = emp['Name'].str.replace(r'\W','',regex=True)   #replace non word charactors

# %%
emp['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp['Domain']
# Out:
# 0     Datascience#$
# 1           Testing
# 2    Dataanalyst^^#
# 3       Ana^^lytics
# 4        Statistics
# 5               NLP
# Name: Domain, dtype: object

# %%
emp['Domain'] = emp['Domain'].str.replace(r'\W','',regex=True)

# %%
emp['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
emp['Age']
# Out:
# 0    34 years
# 1      45' yr
# 2         NaN
# 3         NaN
# 4       67-yr
# 5        55yr
# Name: Age, dtype: object

# %%
emp['Age'] = emp['Age'].str.replace(r'\W','',regex=True)

# %%
emp['Age']
# Out:
# 0    34years
# 1       45yr
# 2        NaN
# 3        NaN
# 4       67yr
# 5       55yr
# Name: Age, dtype: object

# %%
emp['Age'] = emp['Age'].str.extract('(\d+)')

# %%
emp['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
emp['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
emp['Salary']
# Out:
# 0     5^00#0
# 1    10%%000
# 2    1$5%000
# 3     2000^0
# 4     30000-
# 5    6000^$0
# Name: Salary, dtype: object

# %%
emp['Salary'] = emp['Salary'].str.replace(r'\W','',regex=True)

# %%
emp['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
emp['Exp']
# Out:
# 0         2+
# 1         <3
# 2     4> yrs
# 3        NaN
# 4    5+ year
# 5        10+
# Name: Exp, dtype: object

# %%
emp['Exp'] = emp['Exp'].str.extract('(\d+)')

# %%
emp['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
emp
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
clean_data = emp.copy()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %% [markdown]
# # EDA Techniques

# %%
clean_data.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
import numpy as np

# %%
clean_data['Age'] = clean_data['Age'].fillna(np.mean(pd.to_numeric(clean_data['Age'])))

# %%
clean_data['Exp'] = clean_data['Exp'].fillna(np.mean(pd.to_numeric(clean_data['Exp'])))

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
clean_data['Location'] = clean_data['Location'].fillna(clean_data['Location'].mode()[0])

# %%
clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25  Bangalore  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67  Bangalore  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: object(6)
# memory usage: 416.0+ bytes

# %%
clean_data['Name'] = clean_data['Name'].astype('category')
clean_data['Domain'] = clean_data['Domain'].astype('category')
clean_data['Age'] = clean_data['Age'].astype(int)
clean_data['Location'] = clean_data['Location'].astype('category')
clean_data['Salary'] = clean_data['Salary'].astype(int)
clean_data['Exp'] = clean_data['Exp'].astype(int)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int64
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int64
#  5   Exp       6 non-null      int64
# dtypes: category(3), int64(3)
# memory usage: 934.0 bytes
